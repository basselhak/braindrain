# %%
import pandas as pd

# %%
df = pd.read_excel("data/braindrain2.xlsx")

# %%
df
# Out:
#       ID           ARTICLE TITLE                DATE  STAGE  \
# 0      2               E-0148/99 1999-02-11 00:00:00      1
# 1     35               E-0148/99 1999-02-11 00:00:00      1
# 2      1               E-0148/99 1999-02-11 00:00:00      1
# 3     36               E-0148/99 1999-02-11 00:00:00      1
# 4      3               E-0148/99 1999-02-11 00:00:00      1
# 5      4               E-0148/99 1999-02-11 00:00:00      1
# 6      5               E-0148/99 1999-02-11 00:00:00      1
# 7     37               E-0148/99 1999-02-11 00:00:00      1
# 8      7               E-0148/99 1999-02-11 00:00:00      1
# 9      6               E-0148/99 1999-02-11 00:00:00      1
# 10    12               E-1986/01 2001-09-11 00:00:00      1
# 11    38               E-1986/01 2001-09-11 00:00:00      1
# 12     8               E-1986/01 2001-09-11 00:00:00      1
# 13     9               E-1986/01 2001-09-11 00:00:00      1
# 14    11               E-1986/01 2001-09-11 00:00:00      1
# 15    10               E-1248/03 2003-04-02 00:00:00      1
# 16    13               E-1248/03 2003-04-02 00:00:00      1
# 17    14               E-1248/03 2003-04-02 00:00:00      1
# 18    39               E-1248/03 2003-04-02 00:00:00      1
# 19    15               E-1248/03 2003-04-02 00:00:00      1
# 20    16               E-1248/03 2003-04-02 00:00:00      1
# 21    17               E-1248/03 2003-04-02 00:00:00      1
# 22    18               E-1248/03 2003-04-02 00:00:00      1
# 23    20               E-1248/03 2003-04-02 00:00:00      1
# 24    19               E-1248/03 2003-04-02 00:00:00      1
# 25    27               E-1435/03 2003-06-19 00:00:00      1
# 26    40               E-1435/03 2003-06-19 00:00:00      1
# 27    21               E-2986/03 2003-10-09 00:00:00      1
# 28    22               E-2986/03 2003-10-09 00:00:00      1
# 29    23               H-0502/04 2005-01-12 00:00:00      1
# ..   ...                     ...                 ...    ...
# 645  591             E-006121-16 2016-07-29 00:00:00      3
# 646  623             E-007917-16 2016-10-20 00:00:00      3
# 647  625             E-007917-16 2016-10-20 00:00:00      3
# 648  589             E-007917-16 2016-10-20 00:00:00      3
# 649  626             E-008550-16 2016-11-14 00:00:00      3
# 650  627             E-008550-16 2016-11-14 00:00:00      3
# 651  628             E-008550-16 2016-11-14 00:00:00      3
# 652  615             E-009573-16 2016-12-19 00:00:00      3
# 653  617             E-009573-16 2016-12-19 00:00:00      3
# 654  618             E-009573-16 2016-12-19 00:00:00      3
# 655  616             E-009573-16 2016-12-19 00:00:00      3
# 656  619             E-009573-16 2016-12-19 00:00:00      3
# 657  620             E-009573-16 2016-12-19 00:00:00      3
# 658  621             E-009573-16 2016-12-19 00:00:00      3
# 659  667             E-009573-16 2016-12-19 00:00:00      3
# 660  622             E-009573-16 2016-12-19 00:00:00      3
# 661  612           E-001072/2017 2017-03-01 00:00:00      3
# 662  613           E-001072/2017 2017-03-01 00:00:00      3
# 663  466           E-001072/2017 2017-03-01 00:00:00      3
# 664  614           E-001072/2017 2017-03-01 00:00:00      3
# 665  666             E-002963-17 2017-04-27 00:00:00      3
# 666  667             E-002963-17 2017-04-27 00:00:00      3
# 667  668             E-002963-17 2017-04-27 12:00:00      3
# 668  669             E-002963-17 2017-04-27 12:00:00      3
# 669  676             E-002963-17 2017-04-27 12:00:00      3
# 670  675  E-2017-001072 (answer) 2017-05-30 12:00:00      3
# 671  670  E-2017-001072 (answer) 2017-05-30 12:00:00      3
# 672  672  E-2017-001072 (answer) 2017-05-30 12:00:00      3
# 673  673  E-2017-001072 (answer) 2017-05-30 12:00:00      3
# 674  674  E-2017-001072 (answer) 2017-05-30 12:00:00      3
#
#                                PERSON    ORGANIZATION MEP         COUNTRY  \
# 0         Joaquin Sisó Cruellas (EPP)             EPP   Y           Spain
# 1         Joaquin Sisó Cruellas (EPP)             EPP   Y           Spain
# 2         Joaquin Sisó Cruellas (EPP)             EPP   Y           Spain
# 3                       Édith Cresson     DG Research   N          France
# 4                       Édith Cresson     DG Research   N          France
# 5                       Édith Cresson     DG Research   N          France
# 6                       Édith Cresson     DG Research   N          France
# 7                       Édith Cresson     DG Research   N          France
# 8                       Édith Cresson     DG Research   N          France
# 9                       Édith Cresson     DG Research   N          France
# 10              Erik Meijer (GUE/NGL)         GUE/NGL   Y     Netherlands
# 11              Erik Meijer (GUE/NGL)         GUE/NGL   Y     Netherlands
# 12                     Viviane Reding          DG EAC   N      Luxembourg
# 13                     Viviane Reding          DG EAC   N      Luxembourg
# 14                     Viviane Reding          DG EAC   N      Luxembourg
# 15              Brice Hortefeux (EPP)             EPP   Y          France
# 16              Brice Hortefeux (EPP)             EPP   Y          France
# 17              Brice Hortefeux (EPP)             EPP   Y          France
# 18              Brice Hortefeux (EPP)             EPP   Y          France
# 19                   Philippe Busquin     DG Research   N         Belgium
# 20                   Philippe Busquin     DG Research   N         Belgium
# 21                   Philippe Busquin     DG Research   N         Belgium
# 22                   Philippe Busquin     DG Research   N         Belgium
# 23                   Philippe Busquin     DG Research   N         Belgium
# 24                   Philippe Busquin     DG Research   N         Belgium
# 25                       Poul Nielson  DG Development   N         Denmark
# 26                       Poul Nielson  DG Development   N         Denmark
# 27                 Philip Claeys (NI)     Independent   Y         Belgium
# 28                   António Vitorino      DG Justice   N        Portugal
# 29                 Robert Evans (PSE)             S&D   Y  United Kingdom
# ..                                ...             ...  ..             ...
# 645                  Marianne Thyssen   DG Employment   N         Belgium
# 646        Eleftherios Synadinos (NI)     Independent   Y          Greece
# 647              Vytenis Andriukaitis        DG Sanco   N       Lithuania
# 648              Vytenis Andriukaitis        DG Sanco   N       Lithuania
# 649             Norica Nicolai (ALDE)            ALDE   Y         Romania
# 650             Norica Nicolai (ALDE)            ALDE   Y         Romania
# 651             Norica Nicolai (ALDE)            ALDE   Y         Romania
# 652  Dimitrios Papadimoulis (GUE/NGL)         GUE/NGL   Y          Greece
# 653  Dimitrios Papadimoulis (GUE/NGL)         GUE/NGL   Y          Greece
# 654  Dimitrios Papadimoulis (GUE/NGL)         GUE/NGL   Y          Greece
# 655  Dimitrios Papadimoulis (GUE/NGL)         GUE/NGL   Y          Greece
# 656                     Carlos Moedas     DG Research   N        Portugal
# 657                     Carlos Moedas     DG Research   N        Portugal
# 658                     Carlos Moedas     DG Research   N        Portugal
# 659                     Carlos Moedas     DG Research   N        Portugal
# 660                     Carlos Moedas     DG Research   N        Portugal
# 661      Kostas Chrysogonos (GUE/NGL)         GUE/NGL   Y          Greece
# 662      Kostas Chrysogonos (GUE/NGL)         GUE/NGL   Y          Greece
# 663      Kostas Chrysogonos (GUE/NGL)         GUE/NGL   Y          Greece
# 664      Kostas Chrysogonos (GUE/NGL)         GUE/NGL   Y          Greece
# 665            Dominique Martin (ENF)             ENF   Y          France
# 666            Dominique Martin (ENF)             ENF   Y          France
# 667            Dominique Martin (ENF)             ENF   Y          France
# 668                  Marianne Thyssen   DG Employment   N         Belgium
# 669                  Marianne Thyssen   DG Employment   N         Belgium
# 670                  Marianne Thyssen   DG Employment   N         Belgium
# 671                  Marianne Thyssen   DG Employment   N         Belgium
# 672                  Marianne Thyssen   DG Employment   N         Belgium
# 673                  Marianne Thyssen   DG Employment   N         Belgium
# 674                  Marianne Thyssen   DG Employment   N         Belgium
#
#                                CATEGORY  \
# 0    Problem - Third country emigration
# 1          Problem - Working conditions
# 2                        Solution - R&D
# 3          Solution - Increase mobility
# 4                 Solution - Refutation
# 5              Solution - Member States
# 6             Solution - Private sector
# 7                        Solution - R&D
# 8         Solution - Circular migration
# 9              Solution - Member States
# 10                  Problem - Shortages
# 11        Problem - Skills and training
# 12             Solution - Member States
# 13         Solution - Increase mobility
# 14             Solution - Harmonization
# 15   Problem - Third country emigration
# 16         Problem - Working conditions
# 17                        Problem - R&D
# 18            Problem - Competitiveness
# 19                        Problem - R&D
# 20         Problem - Working conditions
# 21                       Solution - R&D
# 22            Solution - Private sector
# 23                       Solution - R&D
# 24        Solution - Working conditions
# 25                Problem - Development
# 26        Solution - Circular migration
# 27                Problem - Development
# 28        Solution - Circular migration
# 29                        Problem - R&D
# ..                                  ...
# 645                      Solution - R&D
# 646             Solution - Job creation
# 647            Solution - Member States
# 648             Solution - Job creation
# 649        Problem - Working conditions
# 650             Problem - Eastern drain
# 651       Solution - Working conditions
# 652                       Problem - R&D
# 653             Problem - Eastern drain
# 654            Problem - Southern drain
# 655           Problem - Economic crisis
# 656                      Solution - R&D
# 657                      Solution - R&D
# 658                      Solution - R&D
# 659          Solution - Cohesion policy
# 660        Solution - Increase mobility
# 661            Problem - Southern drain
# 662           Problem - Economic crisis
# 663                 Problem - Austerity
# 664              Problem - Demographics
# 665               Problem - Development
# 666  Problem - Third country emigration
# 667        Problem - Working conditions
# 668               Solution - Refutation
# 669      Solution - Skills and training
# 670        Solution - Increase mobility
# 671       Solution - Circular migration
# 672      Solution - Skills and training
# 673          Solution - Cohesion policy
# 674             Solution - Job creation
#
#                                                   TEXT
# 0    Participation in international education and t...
# 1    It would appear that the presence of centres o...
# 2    Once abroad, European scientists often find it...
# 3    The Commission is concerned with the trends sh...
# 4    The success of this scholarship scheme proves ...
# 5    In line with the subsidiarity principle, actio...
# 6    As is also indicated in the IPTS report, the E...
# 7    The Commission will continue its efforts to st...
# 8    With regard to the brain drain within the Comm...
# 9    The Commission also encourages the cohesion Me...
# 10   2. Is the Commission also aware, given that 12...
# 11   3. How does the Commission assess the fact tha...
# 12   3. The Commission underlines that, according t...
# 13   4. and 5. The Commission fully supports the cr...
# 14   Furthermore, training conditions for midwives ...
# 15   According to a recent Commission report, nearl...
# 16   researchers currently have better prospects in...
# 17   The EU also spends much less as a whole on res...
# 18   There are also signs of a slowdown in the biot...
# 19   The brain drain and the relatively low levels ...
# 20   The Commission is aware of the situation, whic...
# 21   At the European Council in Barcelona in March ...
# 22   Most of the increase must come from the privat...
# 23   This action plan, Investing in research: an ac...
# 24   To this end, the funding allocated under the 6...
# 25   The report says that ‘facilitating labor mobil...
# 26   While the net effect for developing countries ...
# 27   The emigration of high skilled workers from th...
# 28   In some cases, the costs of brain-drain seem t...
# 29   Currently the European Union's 25 members spen...
# ..                                                 ...
# 645  Almost EUR 20 billion under Horizon 2020 is ea...
# 646  Other than the obvious financial benefits and ...
# 647  As regards healthcare, Member States are respo...
# 648  The ‘European Strategy for more Growth and Job...
# 649  The Commission’s recent amendment to Article 6...
# 650  In practice, universities in Eastern Europe ar...
# 651  How will the Commission reduce inequalities am...
# 652  Many researchers from Eastern and Southern Eur...
# 653  The negative impact from the so-called brain d...
# 654  The negative impact from the so-called brain d...
# 655  All these lead to inequalities between develop...
# 656  Its actions, with a budget of around EUR 800 m...
# 657  Furthermore, support is provided to connect un...
# 658  The Commission also implements the ‘Stairway t...
# 659  In addition, the Cohesion Policy (2014-2020)(1...
# 660  It is expected that these actions will help re...
# 661  Surveys have shown that almost half a million ...
# 662  The main cause of this phenomenon is widesprea...
# 663  which has dramatically worsened during the per...
# 664  The massive exodus of the most competitive and...
# 665  1. By encouraging international mobility, is t...
# 666  2. Why is the Commission promoting such a mech...
# 667  3. By tolerating a brain drain, is the Commiss...
# 668    It is not driving emigration of young Europeans
# 669  With regard to potential brain drain, announce...
# 670  During the crisis it has provided job opportun...
# 671  The Commission is aware of the impacts of mobi...
# 672  In the context of the New Skills Agenda for Eu...
# 673  Structural reforms help improve the economic a...
# 674  The Jobs and Growth Plan for Greece will mobil...
#
# [675 rows x 10 columns]

# %% [markdown]
# Subsetting by Stage number

# %%
df1 = df[df['STAGE'] == 1]
df2 = df[df['STAGE'] == 2]
df3 = df[df['STAGE'] == 3]

# %% [markdown]
# Subsetting again by MEP status

# %%
df1_mep = df1[df1['MEP'] == 'Y']
df1_com = df1[df1['MEP'] == 'N']
df2_mep = df2[df2['MEP'] == 'Y']
df2_com = df2[df2['MEP'] == 'N']
df3_mep = df3[df3['MEP'] == 'Y']
df3_com = df3[df3['MEP'] == 'N']

# %% [markdown]
# Extracting series of counts of each frame occurrence for each subsetted dataframe

# %%
val1_mep = df1_mep['CATEGORY'].value_counts()
val1_com = df1_com['CATEGORY'].value_counts()
val2_mep = df2_mep['CATEGORY'].value_counts()
val2_com = df2_com['CATEGORY'].value_counts()
val3_mep = df3_mep['CATEGORY'].value_counts()
val3_com = df3_com['CATEGORY'].value_counts()

# %% [markdown]
# Calculating those series into percentages

# %%
perc1_mep = 100 * val1_mep / len(df1_mep)
perc1_com = 100 * val1_com / len(df1_com)
perc2_mep = 100 * val2_mep / len(df2_mep)
perc2_com = 100 * val2_com / len(df2_com)
perc3_mep = 100 * val3_mep / len(df3_mep)
perc3_com = 100 * val3_com / len(df3_com)

# %% [markdown]
# Turning the percentage series back into dataframes

# %%
df_mep1 = pd.DataFrame({'Frames': perc1_mep.index, 'MEP 1': perc1_mep.values})
df_com1 = pd.DataFrame({'Frames': perc1_com.index, 'COM 1': perc1_com.values})
df_mep2 = pd.DataFrame({'Frames': perc2_mep.index, 'MEP 2': perc2_mep.values})
df_com2 = pd.DataFrame({'Frames': perc2_com.index, 'COM 2': perc2_com.values})
df_mep3 = pd.DataFrame({'Frames': perc3_mep.index, 'MEP 3': perc3_mep.values})
df_com3 = pd.DataFrame({'Frames': perc3_com.index, 'COM 3': perc3_com.values})

# %% [markdown]
# Setting the index of each dataframe to the 'Frames' column.

# %%
df_mep1i = df_mep1.set_index('Frames')
df_com1i = df_com1.set_index('Frames')
df_mep2i = df_mep2.set_index('Frames')
df_com2i = df_com2.set_index('Frames')
df_mep3i = df_mep3.set_index('Frames')
df_com3i = df_com3.set_index('Frames')

# %% [markdown]
# Merging the re-indexed dataframes one-by-one to get the final dataframe.

# %%
result1 = df_mep1i.join(df_com1i, how='outer')
result2 = result1.join(df_mep2i, how='outer')
result3 = result2.join(df_com2i, how='outer')
result4 = result3.join(df_mep3i, how='outer')
result5 = result4.join(df_com3i, how='outer')

# %%
result5
# Out:
#                                         MEP 1      COM 1      MEP 2  \
# Frames
# Problem - Austerity                       NaN        NaN   3.007519
# Problem - Competitiveness            8.196721   0.869565        NaN
# Problem - Demographics               1.639344   0.869565   0.751880
# Problem - Development               18.032787   6.086957   6.015038
# Problem - Eastern drain              4.918033        NaN   4.511278
# Problem - Economic crisis                 NaN        NaN   8.270677
# Problem - R&D                       11.475410   1.739130   6.766917
# Problem - Shortages                  6.557377   5.217391   4.511278
# Problem - Skills and training        1.639344        NaN   4.511278
# Problem - Southern drain                  NaN        NaN  10.526316
# Problem - Third country emigration  13.114754   1.739130   6.015038
# Problem - Working conditions         9.836066   3.478261   3.759398
# Problem - Youth unemployment         1.639344   0.869565  12.030075
# Solution - Austerity                      NaN        NaN        NaN
# Solution - Circular migration        3.278689  14.782609   2.255639
# Solution - Cohesion policy           3.278689   0.869565   5.263158
# Solution - Development               1.639344   0.869565        NaN
# Solution - Harmonization                  NaN   3.478261        NaN
# Solution - Increase mobility              NaN  13.043478   1.503759
# Solution - Job creation              1.639344   4.347826   4.511278
# Solution - Member States                  NaN   6.956522        NaN
# Solution - Private sector                 NaN   5.217391   3.007519
# Solution - R&D                       4.918033   7.826087   1.503759
# Solution - Refutation                     NaN   6.956522        NaN
# Solution - Restrict mobility         6.557377        NaN   3.007519
# Solution - Skills and training            NaN   5.217391   4.511278
# Solution - Working conditions        1.639344   9.565217   3.759398
#
#                                         COM 2      MEP 3      COM 3
# Frames
# Problem - Austerity                  0.584795   4.494382        NaN
# Problem - Competitiveness                 NaN        NaN        NaN
# Problem - Demographics                    NaN   4.494382   2.830189
# Problem - Development                2.339181   2.247191        NaN
# Problem - Eastern drain              0.584795  12.359551   1.886792
# Problem - Economic crisis            1.169591  10.112360        NaN
# Problem - R&D                        1.169591   6.741573        NaN
# Problem - Shortages                  4.093567   6.741573   3.773585
# Problem - Skills and training        1.169591   1.123596        NaN
# Problem - Southern drain             1.169591  12.359551   0.943396
# Problem - Third country emigration        NaN   7.865169   1.886792
# Problem - Working conditions              NaN  13.483146   2.830189
# Problem - Youth unemployment         3.508772   1.123596        NaN
# Solution - Austerity                 1.169591        NaN   0.943396
# Solution - Circular migration        8.187135        NaN   5.660377
# Solution - Cohesion policy           7.602339        NaN  13.207547
# Solution - Development               2.923977        NaN        NaN
# Solution - Harmonization             4.678363        NaN   1.886792
# Solution - Increase mobility        12.865497        NaN  14.150943
# Solution - Job creation              7.017544   2.247191   4.716981
# Solution - Member States             4.678363        NaN   6.603774
# Solution - Private sector            3.508772        NaN        NaN
# Solution - R&D                       3.508772   2.247191  10.377358
# Solution - Refutation                8.187135        NaN   8.490566
# Solution - Restrict mobility              NaN   7.865169        NaN
# Solution - Skills and training      12.280702        NaN  10.377358
# Solution - Working conditions        7.602339   4.494382   9.433962

# %% [markdown]
# Importing packages for plotting

# %%
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# Subsetting the final dataframe according to each stage of the policy debate.

# %%
stage_1 = result5.iloc[:,0:2]
stage_2 = result5.iloc[:,2:4]
stage_3 = result5.iloc[:,4:6]

# %% [markdown]
# These can be plotted as below.

# %%
stage_1.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
stage_2.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
stage_3.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Stacking the bars is also an option, for example:

# %%
stage_3.plot.bar(stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# But I'm not satisfied with the readability of these graphs. I think a Facet Grid where I go frame by frame and show the evolution of the usage of each frame by each group over each stage of the debate is more helpful. As an example, see below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In order to get this sort of chart for the brain drain data, I need to reorganize the final dataframe (result5) in the below format. I did this by hand (using the values in the result5 dataframe), as I'm not sure how to achieve this in Python.

# %%
df_facet = pd.read_excel('data/bd_facetgrid.xlsx')
df_facet
# Out:
#                               Frame Group  Stage  Percentage
# 0               Problem - Austerity   MEP      1        0.00
# 1               Problem - Austerity   MEP      2        3.00
# 2               Problem - Austerity   MEP      3        4.49
# 3               Problem - Austerity    EC      1        0.00
# 4               Problem - Austerity    EC      2        0.58
# 5               Problem - Austerity    EC      3        0.00
# 6         Problem - Competitiveness   MEP      1        8.20
# 7         Problem - Competitiveness   MEP      2        0.00
# 8         Problem - Competitiveness   MEP      3        0.00
# 9         Problem - Competitiveness    EC      1        0.87
# 10        Problem - Competitiveness    EC      2        0.00
# 11        Problem - Competitiveness    EC      3        0.00
# 12           Problem - Demographics   MEP      1        1.64
# 13           Problem - Demographics   MEP      2        0.75
# 14           Problem - Demographics   MEP      3        4.49
# 15           Problem - Demographics    EC      1        0.87
# 16           Problem - Demographics    EC      2        0.00
# 17           Problem - Demographics    EC      3        2.83
# 18            Problem - Development   MEP      1       18.03
# 19            Problem - Development   MEP      2        6.02
# 20            Problem - Development   MEP      3        2.25
# 21            Problem - Development    EC      1        6.09
# 22            Problem - Development    EC      2        2.34
# 23            Problem - Development    EC      3        0.00
# 24          Problem - Eastern drain   MEP      1        4.92
# 25          Problem - Eastern drain   MEP      2        4.51
# 26          Problem - Eastern drain   MEP      3       12.36
# 27          Problem - Eastern drain    EC      1        0.00
# 28          Problem - Eastern drain    EC      2        0.58
# 29          Problem - Eastern drain    EC      3        1.89
# ..                              ...   ...    ...         ...
# 132                  Solution - R&D   MEP      1        4.92
# 133                  Solution - R&D   MEP      2        1.50
# 134                  Solution - R&D   MEP      3        2.25
# 135                  Solution - R&D    EC      1        7.83
# 136                  Solution - R&D    EC      2        3.51
# 137                  Solution - R&D    EC      3       10.38
# 138           Solution - Refutation   MEP      1        0.00
# 139           Solution - Refutation   MEP      2        0.00
# 140           Solution - Refutation   MEP      3        0.00
# 141           Solution - Refutation    EC      1        6.96
# 142           Solution - Refutation    EC      2        8.19
# 143           Solution - Refutation    EC      3        8.49
# 144    Solution - Restrict mobility   MEP      1        6.56
# 145    Solution - Restrict mobility   MEP      2        3.01
# 146    Solution - Restrict mobility   MEP      3        7.87
# 147    Solution - Restrict mobility    EC      1        0.00
# 148    Solution - Restrict mobility    EC      2        0.00
# 149    Solution - Restrict mobility    EC      3        0.00
# 150  Solution - Skills and training   MEP      1        0.00
# 151  Solution - Skills and training   MEP      2        4.51
# 152  Solution - Skills and training   MEP      3        0.00
# 153  Solution - Skills and training    EC      1        5.22
# 154  Solution - Skills and training    EC      2       12.28
# 155  Solution - Skills and training    EC      3       10.38
# 156   Solution - Working conditions   MEP      1        1.64
# 157   Solution - Working conditions   MEP      2        3.76
# 158   Solution - Working conditions   MEP      3        4.49
# 159   Solution - Working conditions    EC      1        9.57
# 160   Solution - Working conditions    EC      2        7.60
# 161   Solution - Working conditions    EC      3        9.43
#
# [162 rows x 4 columns]

# %% [markdown]
# The formatted dataframe is easily turned into a facet grid with the Seaborn package.

# %%
g = sns.FacetGrid(df_facet, col="Frame", hue="Group", palette='Set1', col_wrap=9, size=3.0)
g = g.map(plt.plot, "Stage", "Percentage", marker=".").set(xticks=[1, 2, 3])
# Out:
# <img src="data:image/png;base64,..." width="1728">

# %%
g.savefig('exports/facetgrid.pdf')

# %% [markdown]
# This figure is still too large. I can subset the dataframe and create two figures - one for problems and one for solutions.

# %%
df_problems = df_facet.iloc[0:78,:]
df_problems
# Out:
#                                  Frame Group  Stage  Percentage
# 0                  Problem - Austerity   MEP      1        0.00
# 1                  Problem - Austerity   MEP      2        3.00
# 2                  Problem - Austerity   MEP      3        4.49
# 3                  Problem - Austerity    EC      1        0.00
# 4                  Problem - Austerity    EC      2        0.58
# 5                  Problem - Austerity    EC      3        0.00
# 6            Problem - Competitiveness   MEP      1        8.20
# 7            Problem - Competitiveness   MEP      2        0.00
# 8            Problem - Competitiveness   MEP      3        0.00
# 9            Problem - Competitiveness    EC      1        0.87
# 10           Problem - Competitiveness    EC      2        0.00
# 11           Problem - Competitiveness    EC      3        0.00
# 12              Problem - Demographics   MEP      1        1.64
# 13              Problem - Demographics   MEP      2        0.75
# 14              Problem - Demographics   MEP      3        4.49
# 15              Problem - Demographics    EC      1        0.87
# 16              Problem - Demographics    EC      2        0.00
# 17              Problem - Demographics    EC      3        2.83
# 18               Problem - Development   MEP      1       18.03
# 19               Problem - Development   MEP      2        6.02
# 20               Problem - Development   MEP      3        2.25
# 21               Problem - Development    EC      1        6.09
# 22               Problem - Development    EC      2        2.34
# 23               Problem - Development    EC      3        0.00
# 24             Problem - Eastern drain   MEP      1        4.92
# 25             Problem - Eastern drain   MEP      2        4.51
# 26             Problem - Eastern drain   MEP      3       12.36
# 27             Problem - Eastern drain    EC      1        0.00
# 28             Problem - Eastern drain    EC      2        0.58
# 29             Problem - Eastern drain    EC      3        1.89
# ..                                 ...   ...    ...         ...
# 48       Problem - Skills and training   MEP      1        1.64
# 49       Problem - Skills and training   MEP      2        4.51
# 50       Problem - Skills and training   MEP      3        1.12
# 51       Problem - Skills and training    EC      1        0.00
# 52       Problem - Skills and training    EC      2        1.17
# 53       Problem - Skills and training    EC      3        0.00
# 54            Problem - Southern drain   MEP      1        0.00
# 55            Problem - Southern drain   MEP      2       10.53
# 56            Problem - Southern drain   MEP      3       12.36
# 57            Problem - Southern drain    EC      1        0.00
# 58            Problem - Southern drain    EC      2        1.17
# 59            Problem - Southern drain    EC      3        0.94
# 60  Problem - Third country emigration   MEP      1       13.11
# 61  Problem - Third country emigration   MEP      2        6.02
# 62  Problem - Third country emigration   MEP      3        7.87
# 63  Problem - Third country emigration    EC      1        1.74
# 64  Problem - Third country emigration    EC      2        0.00
# 65  Problem - Third country emigration    EC      3        1.87
# 66        Problem - Working conditions   MEP      1        9.84
# 67        Problem - Working conditions   MEP      2        3.76
# 68        Problem - Working conditions   MEP      3       13.48
# 69        Problem - Working conditions    EC      1        3.48
# 70        Problem - Working conditions    EC      2        0.00
# 71        Problem - Working conditions    EC      3        2.83
# 72        Problem - Youth unemployment   MEP      1        1.64
# 73        Problem - Youth unemployment   MEP      2       12.03
# 74        Problem - Youth unemployment   MEP      3        1.12
# 75        Problem - Youth unemployment    EC      1        0.87
# 76        Problem - Youth unemployment    EC      2        3.51
# 77        Problem - Youth unemployment    EC      3        0.00
#
# [78 rows x 4 columns]

# %%
df_solutions = df_facet.iloc[78:,:]
df_solutions
# Out:
#                               Frame Group  Stage  Percentage
# 78             Solution - Austerity   MEP      1        0.00
# 79             Solution - Austerity   MEP      2        0.00
# 80             Solution - Austerity   MEP      3        0.00
# 81             Solution - Austerity    EC      1        0.00
# 82             Solution - Austerity    EC      2        1.17
# 83             Solution - Austerity    EC      3        0.94
# 84    Solution - Circular migration   MEP      1        3.28
# 85    Solution - Circular migration   MEP      2        2.26
# 86    Solution - Circular migration   MEP      3        0.00
# 87    Solution - Circular migration    EC      1       14.78
# 88    Solution - Circular migration    EC      2        8.19
# 89    Solution - Circular migration    EC      3        5.66
# 90       Solution - Cohesion policy   MEP      1        3.28
# 91       Solution - Cohesion policy   MEP      2        5.26
# 92       Solution - Cohesion policy   MEP      3        0.00
# 93       Solution - Cohesion policy    EC      1        0.87
# 94       Solution - Cohesion policy    EC      2        7.60
# 95       Solution - Cohesion policy    EC      3       13.21
# 96           Solution - Development   MEP      1        1.64
# 97           Solution - Development   MEP      2        0.00
# 98           Solution - Development   MEP      3        0.00
# 99           Solution - Development    EC      1        0.87
# 100          Solution - Development    EC      2        2.92
# 101          Solution - Development    EC      3        0.00
# 102        Solution - Harmonization   MEP      1        0.00
# 103        Solution - Harmonization   MEP      2        0.00
# 104        Solution - Harmonization   MEP      3        0.00
# 105        Solution - Harmonization    EC      1        3.48
# 106        Solution - Harmonization    EC      2        4.68
# 107        Solution - Harmonization    EC      3        1.89
# ..                              ...   ...    ...         ...
# 132                  Solution - R&D   MEP      1        4.92
# 133                  Solution - R&D   MEP      2        1.50
# 134                  Solution - R&D   MEP      3        2.25
# 135                  Solution - R&D    EC      1        7.83
# 136                  Solution - R&D    EC      2        3.51
# 137                  Solution - R&D    EC      3       10.38
# 138           Solution - Refutation   MEP      1        0.00
# 139           Solution - Refutation   MEP      2        0.00
# 140           Solution - Refutation   MEP      3        0.00
# 141           Solution - Refutation    EC      1        6.96
# 142           Solution - Refutation    EC      2        8.19
# 143           Solution - Refutation    EC      3        8.49
# 144    Solution - Restrict mobility   MEP      1        6.56
# 145    Solution - Restrict mobility   MEP      2        3.01
# 146    Solution - Restrict mobility   MEP      3        7.87
# 147    Solution - Restrict mobility    EC      1        0.00
# 148    Solution - Restrict mobility    EC      2        0.00
# 149    Solution - Restrict mobility    EC      3        0.00
# 150  Solution - Skills and training   MEP      1        0.00
# 151  Solution - Skills and training   MEP      2        4.51
# 152  Solution - Skills and training   MEP      3        0.00
# 153  Solution - Skills and training    EC      1        5.22
# 154  Solution - Skills and training    EC      2       12.28
# 155  Solution - Skills and training    EC      3       10.38
# 156   Solution - Working conditions   MEP      1        1.64
# 157   Solution - Working conditions   MEP      2        3.76
# 158   Solution - Working conditions   MEP      3        4.49
# 159   Solution - Working conditions    EC      1        9.57
# 160   Solution - Working conditions    EC      2        7.60
# 161   Solution - Working conditions    EC      3        9.43
#
# [84 rows x 4 columns]

# %% [markdown]
# Now I create two final facet grids using the problem and solution dataframes.

# %%
g1 = sns.FacetGrid(df_problems, col="Frame", hue="Group", palette='Set1', col_wrap=4, size=3.0)
g1.map(plt.plot, "Stage", "Percentage", marker=".").set(xticks=[1, 2, 3])
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
g2 = sns.FacetGrid(df_solutions, col="Frame", hue="Group", palette='Set1', col_wrap=4, size=3.0)
g2.map(plt.plot, "Stage", "Percentage", marker=".").set(xticks=[1, 2, 3])
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
g1.savefig('exports/problems.pdf')
g2.savefig('exports/solutions.pdf')
